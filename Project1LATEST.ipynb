# %%
# Import dependencies
import requests
import os
import pprint
from datetime import datetime,timedelta
import json
import pandas as pd
from dateutil.parser import parse
import itertools
from itertools import permutations
import tqdm 
from tqdm import tqdm

# %%
# Set params for query
pax = input(' # of adults will be traveling?')
children = input(' # Children traveling with you?')
p0 = input(' Starting place') 
startdate = input('Trip start date (mm/dd/yyyy)')
destinations = input('List the cities do you want to travel to? And how many days per city? ex(London,4,Madrid,3)')
destinations.replace(" ", "")
destinations1 = list(destinations.split(','))
# Out:
#  # of adults will be traveling?1
#  # Children traveling with you?0
#  Starting placemiami
# Trip start date (mm/dd/yyyy)12/01/2019
# List the cities do you want to travel to? And how many days per city? ex(London,4,Madrid,3)london,3,madrid,2,paris,4

# %%
p1=(str(destinations1[0]),int(destinations1[1]))
p2 = (str(destinations1[2]), int(destinations1[3]))
p3 = (str(destinations1[4]), int(destinations1[5]))

def changeorder(res,p1,p2,p3,startdate,p0,children,pax):
    

    start_date = parse(startdate)
    days_p1=p1[1]
    days_p2=p2[1]
    days_p3=p3[1]
    start_p1 = start_date + timedelta(days=days_p1)
    start_p2 = start_p1 + timedelta(days=days_p2)
    start_p3 = start_p2 + timedelta(days=days_p3)
    url = "https://apidojo-hipmunk-v1.p.rapidapi.com/flights/create-session"

    querystring = {"from1":p1[0],"from2":p2[0],"from3":p3[0],"to1":p2[0],"to2":p3[0],"to3":p0,"date1":start_p1,"date2":start_p2,"date3":start_p3,"infants_lap":"0","children":children,"seniors":"0","country":"US","from0":p0,"to0":p1[0],"date0":startdate,"pax":pax,"cabin":"Coach"}
    headers = {
        'x-rapidapi-host': "apidojo-hipmunk-v1.p.rapidapi.com",
        'x-rapidapi-key': "f52da07954msh79f61d44ab028c2p138041jsne9cd9d426802"
        }

    response = requests.request("GET", url, headers=headers, params=querystring).json()

    #does stuff with response
    idnums=[]
    agonies=[]
    prices=[]
    routingid=[]

    for key,value in response['itins'].items():
        idnum=key
        agony=value['agony']
        price=value['price']
        routing_id=value['routing_idens']
        idnums.append(idnum)
        agonies.append(agony)
        prices.append(price)
        routingid.append(routing_id)
    df=pd.DataFrame()
    df['price']=prices
    df['agonies']=agonies
    df['id']=idnums
    df['routing']=routingid
    
    


    # Print DF with values
    df = df.sort_values(['price'], ascending=[True])
    df = df[:5]

    res.append([(p1,p2,p3),df])



    #p1,p2,p3 = p2,p3,p1
    return res

# %%
#res=[]
#for _ in tqdm(range(3)):
#    p1,p2,p3,response=changeorder(p1,p2,p3,startdate,p0,children,pax)
    
#res

# %%
alist = []
listA = [p1, p2, p3]
perm = itertools.permutations(listA) 
  
for i in tqdm(list(perm)): 
    alist.append(i)
  
alist
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 26078.57it/s]
# [(('london', 3), ('madrid', 2), ('paris', 4)),
#  (('london', 3), ('paris', 4), ('madrid', 2)),
#  (('madrid', 2), ('london', 3), ('paris', 4)),
#  (('madrid', 2), ('paris', 4), ('london', 3)),
#  (('paris', 4), ('london', 3), ('madrid', 2)),
#  (('paris', 4), ('madrid', 2), ('london', 3))]

# %%
print('Sorry, this may take a while...')
res=[]
for i in tqdm(alist):
    p1,p2,p3=i[0],i[1],i[2]
    res=changeorder(res,p1,p2,p3,startdate,p0,children,pax)
    
res

# %%
df1=pd.DataFrame(res[0][1])
df2=pd.DataFrame(res[1][1])
df3=pd.DataFrame(res[2][1])
df4=pd.DataFrame(res[3][1])
df5=pd.DataFrame(res[4][1])
df6=pd.DataFrame(res[5][1])

# %%
response
# Out:
# {'cabin_map': {'0': 'Basic Coach',
#   '1': 'Coach',
#   '2': 'Premium Coach',
#   '3': 'Business',
#   '4': 'First',
#   '5': 'Air Taxi'},
#  'booking_agent': {'clienttype': 'web',
#   'mobile': '',
#   'platform': 'web',
#   'is_app': False,
#   'version': '',
#   'revision': 1},
#  'suggestions': {},
#  'airlines': {'AA': {'color': '#A60000',
#    'name': 'American',
#    'short_name': 'American'},
#   'BE': {'color': '#4B0082', 'name': 'Flybe', 'short_name': 'Flybe'},
#   'AC': {'color': '#B22222', 'name': 'Air Canada', 'short_name': 'Air Canada'},
#   'VY': {'color': '#4B0082', 'name': 'Vueling', 'short_name': 'Vueling'},
#   'EI': {'color': '#4AA43F', 'name': 'Aer Lingus', 'short_name': 'Aer Lingus'},
#   'BA': {'color': '#FF4500', 'name': 'British', 'short_name': 'British'},
#   'AF': {'color': '#CD5C5C', 'name': 'Air France', 'short_name': 'Air France'},
#   'UA': {'color': '#0000A6', 'name': 'United', 'short_name': 'United'},
#   'TP': {'color': '#66B745', 'name': 'TAP', 'short_name': 'TAP'},
#   'LG': {'color': '#4B0082', 'name': 'Luxair', 'short_name': 'Luxair'},
#   'B6': {'color': '#0000e6', 'name': 'JetBlue', 'short_name': 'JetBlue'},
#   'UX': {'color': '#48D1CC', 'name': 'Air Europa', 'short_name': 'Air Europa'},
#   'LH': {'color': '#FF8C00', 'name': 'Lufthansa', 'short_name': 'Lufthansa'},
#   'SU': {'color': '#6495ED', 'name': 'Aeroflot', 'short_name': 'Aeroflot'},
#   'DY': {'color': '#4B0082',
#    'name': 'Norwegian Air Shuttle',
#    'short_name': 'Norwegian Air Shuttle'},
#   'AY': {'color': '#0359A2', 'name': 'Finnair', 'short_name': 'Finnair'},
#   'D8': {'color': '#4B0082',
#    'name': 'Norwegian Air International',
#    'short_name': 'Norwegian Air International'},
#   'IB': {'color': '#DF1D3F', 'name': 'Iberia', 'short_name': 'Iberia'},
#   'OS': {'color': '#EC1F27', 'name': 'Austrian', 'short_name': 'Austrian'},
#   'LX': {'color': '#000080', 'name': 'Swiss', 'short_name': 'Swiss'},
#   'AT': {'color': '#4B0082',
#    'name': 'Royal Air Maroc',
#    'short_name': 'Royal Air Maroc'}},
#  'itins': {'e215fcf285ee367d046f417d300981aa': {'dependability_score': 18,
#    'iden': 'e215fcf285ee367d046f417d300981aa',
#    'agony': 8811.438101135733,
#    'price': 4850.0,
#    'unrounded_price': 4849.75,
#    'booking_urls': {'9WouQQG': {'original_price': 4849.75,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': 4406.0,
#      'sort_rank': 0,
#      'price': 4850.0,
#      'iden': '9WouQQG',
#      'milefy': [{'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 4640.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 989.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 0.0,
#         'qualifying_miles': 773.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 4580.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': [None, None, None, None, None, None, None],
#       'rbds': ['K', 'K', 'Y', 'Y', 'Y', 'Y', 'Y']},
#      'url_type': 'web',
#      'unrounded_price': 4849.75,
#      'provider_type': 'AIR',
#      'name': 'AA'}},
#    'routing_idens': ['43e2be330e1a0e9e497b4146a67e5323',
#     '86a00da2fad6bfe2d1a7097985958a42',
#     '03a28d5ff6f21826d4dd8d7969b6900a',
#     'd4785efad6c995f4d026919c51f77a3d'],
#    'bundle_iden': '2733af79b65efc48c72deac70c5ca7af'},
#   '02990b45dc83377cd41cb5c48277f478': {'dependability_score': -3,
#    'iden': '02990b45dc83377cd41cb5c48277f478',
#    'agony': 8540.596016603211,
#    'price': 4679.0,
#    'unrounded_price': 4678.85,
#    'booking_urls': {'gEqzC4R': {'original_price': 4678.85,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': 4247.0,
#      'sort_rank': 0,
#      'price': 4679.0,
#      'iden': 'gEqzC4R',
#      'milefy': [{'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 4741.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 989.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 0.0,
#         'qualifying_miles': 773.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 5095.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': [None, None, None, None, None, None, None],
#       'rbds': ['K', 'K', 'Y', 'Y', 'Y', 'Y', 'Y']},
#      'url_type': 'web',
#      'unrounded_price': 4678.85,
#      'provider_type': 'AIR',
#      'name': 'AA'}},
#    'routing_idens': ['6644277f7eab7a506e0736b376c8f9c1',
#     '86a00da2fad6bfe2d1a7097985958a42',
#     'b0c98223e2fd695b544df5776f6771e8',
#     '95c9a21bb3e3d2ba09257fb5b4f3dda0'],
#    'bundle_iden': '3183895be1c4555de70b9e4c4955a0df'},
#   'b49a0246871761b151fd60ba9e6dd640': {'dependability_score': 33,
#    'iden': 'b49a0246871761b151fd60ba9e6dd640',
#    'agony': 5558.964897243925,
#    'price': 2682.0,
#    'unrounded_price': 2681.85,
#    'booking_urls': {'j21yoIC': {'original_price': 2681.85,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2682.0,
#      'iden': 'j21yoIC',
#      'milefy': [{'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2423.0,
#         'qualifying_miles': 2423.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 0.0,
#         'qualifying_miles': 1121.0,
#         'qualifying_points': 0.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': ['TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'KKA00NCT',
#        'KKA00NCT',
#        'TL247NCV',
#        'TL247NCV'],
#       'rbds': ['T', 'T', 'T', 'T', 'K', 'K', 'T', 'T']},
#      'url_type': 'web',
#      'unrounded_price': 2681.85,
#      'provider_type': 'OTA',
#      'name': 'Expedia'}},
#    'routing_idens': ['3c574998c62b269adb8e6325f772c74f',
#     'ccef718f2207200f38e3b413bed9361c',
#     'ac99c181d07f8a8ce646d319d56ebebf',
#     '3fa675c4ee208633aefa86ea26599d8a'],
#    'bundle_iden': 'b8c0eafb7a2598041e8f5e6caebee379'},
#   '7c3b8258ea2252bfebccd9e743327f53': {'dependability_score': 33,
#    'iden': '7c3b8258ea2252bfebccd9e743327f53',
#    'agony': 5800.860580993324,
#    'price': 2845.0,
#    'unrounded_price': 2844.65,
#    'booking_urls': {'abN9bcl': {'original_price': 2844.65,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2845.0,
#      'iden': 'abN9bcl',
#      'milefy': [{'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2412.0,
#         'qualifying_miles': 2412.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 0.0,
#         'qualifying_miles': 1121.0,
#         'qualifying_points': 0.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': ['TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'KKA00NCT',
#        'KKA00NCT',
#        'TL247NCV',
#        'TL247NCV'],
#       'rbds': ['T', 'T', 'T', 'T', 'K', 'K', 'T', 'T']},
#      'url_type': 'web',
#      'unrounded_price': 2844.65,
#      'provider_type': 'OTA',
#      'name': 'Expedia'}},
#    'routing_idens': ['2a590900a564b5dfdaf9c2a84c2e8f65',
#     'ec139eeb1a6d1d886ea8c3143d47c2ff',
#     'ac99c181d07f8a8ce646d319d56ebebf',
#     'ba885285c138f70c00b29aa681a09fde'],
#    'bundle_iden': '9ab7f326e084c64d095a39aca40c5580'},
#   'c6b51ff5303f64f12ba93f5083036872': {'dependability_score': 0,
#    'iden': 'c6b51ff5303f64f12ba93f5083036872',
#    'agony': 4837.409550356303,
#    'price': 2492.0,
#    'unrounded_price': 2491.06,
#    'booking_urls': {'2v4TQ1e': {'original_price': 2491.06,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2492.0,
#      'iden': '2v4TQ1e',
#      'leg_details': {'branded_fares': [None, None, None, None],
#       'fare_basis_codes': [None, None, None, None],
#       'rbds': [None, None, None, None]},
#      'url_type': 'web',
#      'unrounded_price': 2491.06,
#      'provider_type': 'OTA',
#      'name': 'CheapOair'}},
#    'routing_idens': ['5cfe716588fc593c50667a432f10c95d',
#     '6300a0eaf27c983cc8aab4ee553c562f',
#     '1a8b9f134ef48d496225d498f6567b36',
#     '096c640d7296f8bc38c648ce118a56cc'],
#    'bundle_iden': 'f8b652651b0dc54024e4beb6a4f7592a'},
#   '5265314bc23804fbab91902693234e81': {'dependability_score': 0,
#    'iden': '5265314bc23804fbab91902693234e81',
#    'agony': 5348.343281946598,
#    'price': 2508.0,
#    'unrounded_price': 2507.74,
#    'booking_urls': {'25G7DDP': {'original_price': 2507.74,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2508.0,
#      'iden': '25G7DDP',
#      'milefy': [{'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2423.0,
#         'qualifying_miles': 2423.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2363.0,
#         'qualifying_miles': 2363.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': ['TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT'],
#       'rbds': ['T', 'T', 'T', 'T', 'K', 'K', 'K', 'K']},
#      'url_type': 'web',
#      'unrounded_price': 2507.74,
#      'provider_type': 'OTA',
#      'name': 'Expedia'}},
#    'routing_idens': ['877898649fc1f4dbd6bb3136ae9d65c2',
#     'f0db0af345593428a62743bf4d6b2de8',
#     'ac99c181d07f8a8ce646d319d56ebebf',
#     'cefc2e460db6995c15b8d982539cebba'],
#    'bundle_iden': '9065a1a7227abc12e7fe8c343165551a'},
#   'b8a3003e3e84bdf1bea58b929a240cfe': {'dependability_score': 0,
#    'iden': 'b8a3003e3e84bdf1bea58b929a240cfe',
#    'agony': 5263.220961849796,
#    'price': 2526.0,
#    'unrounded_price': 2525.34,
#    'booking_urls': {'fF9eGnj': {'original_price': 2525.34,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2526.0,
#      'iden': 'fF9eGnj',
#      'milefy': [{'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2412.0,
#         'qualifying_miles': 2412.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2384.0,
#         'qualifying_miles': 2384.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': ['SL347NCV',
#        'SL347NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT'],
#       'rbds': ['S', 'S', 'T', 'T', 'K', 'K', 'K', 'K']},
#      'url_type': 'web',
#      'unrounded_price': 2525.34,
#      'provider_type': 'OTA',
#      'name': 'Travelocity'}},
#    'routing_idens': ['23f2663ea5871e78c6c7ee7b0743e97b',
#     'f0db0af345593428a62743bf4d6b2de8',
#     'aa89379f8a7c70868caede682cfe8b8f',
#     '6f3f03e6228851afe5cd162a573b4f2c'],
#    'bundle_iden': '3ca92f1ca2f89c32c0750a6ecaf881a0'},
#   '6542a9f8e6d78b9db760d555fc5ee3ee': {'dependability_score': 0,
#    'iden': '6542a9f8e6d78b9db760d555fc5ee3ee',
#    'agony': 5299.598924708139,
#    'price': 2517.0,
#    'unrounded_price': 2516.93,
#    'booking_urls': {'hU7UOjj': {'original_price': 2516.93,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2517.0,
#      'iden': 'hU7UOjj',
#      'milefy': [{'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2460.0,
#         'qualifying_miles': 2460.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2384.0,
#         'qualifying_miles': 2384.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': ['TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT'],
#       'rbds': ['T', 'T', 'T', 'T', 'K', 'K', 'K', 'K']},
#      'url_type': 'web',
#      'unrounded_price': 2516.93,
#      'provider_type': 'OTA',
#      'name': 'Expedia'}},
#    'routing_idens': ['32e93ecf674d32c5807f142ec905573f',
#     'ec139eeb1a6d1d886ea8c3143d47c2ff',
#     'ffa65a21f762670d4b3ec80fdf25be1d',
#     'f1935800868111ef65e2bd375d3c151e'],
#    'bundle_iden': '51d71416a96c7ee7a3a81983b78b2a98'},
#   '3b03fd2c1042bd020ae1e621b420fc2d': {'dependability_score': 60,
#    'iden': '3b03fd2c1042bd020ae1e621b420fc2d',
#    'agony': 8560.387506213303,
#    'price': 4708.0,
#    'unrounded_price': 4707.85,
#    'booking_urls': {'3RHdrG0': {'original_price': 4707.85,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': 4276.0,
#      'sort_rank': 0,
#      'price': 4708.0,
#      'iden': '3RHdrG0',
#      'milefy': [{'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 4720.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 989.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 0.0,
#         'qualifying_miles': 773.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 4641.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': [None, None, None, None, None, None, None],
#       'rbds': ['H', 'H', 'Y', 'Y', 'Y', 'Y', 'Y']},
#      'url_type': 'web',
#      'unrounded_price': 4707.85,
#      'provider_type': 'AIR',
#      'name': 'AA'}},
#    'routing_idens': ['d950c7f5f0228435654ccaf2d116826b',
#     '86a00da2fad6bfe2d1a7097985958a42',
#     'f682643cc09a16a9fcc226fba4b56d75',
#     '73f2365b43fb23b937b34a9946b6c6a7'],
#    'bundle_iden': 'fbaf2e19c7a99b3424a6701686b10a3d'},
#   'e1007067768060c93bd224970ac09af6': {'dependability_score': -3,
#    'iden': 'e1007067768060c93bd224970ac09af6',
#    'agony': 8496.448689913752,
#    'price': 4651.0,
#    'unrounded_price': 4650.85,
#    'booking_urls': {'5phKuFc': {'original_price': 4650.85,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': 4219.0,
#      'sort_rank': 0,
#      'price': 4651.0,
#      'iden': '5phKuFc',
#      'milefy': [{'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 4741.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 989.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 0.0,
#         'qualifying_miles': 773.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 5133.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': [None, None, None, None, None, None, None],
#       'rbds': ['K', 'K', 'Y', 'Y', 'Y', 'Y', 'Y']},
#      'url_type': 'web',
#      'unrounded_price': 4650.85,
#      'provider_type': 'AIR',
#      'name': 'AA'}},
#    'routing_idens': ['6644277f7eab7a506e0736b376c8f9c1',
#     '86a00da2fad6bfe2d1a7097985958a42',
#     'f682643cc09a16a9fcc226fba4b56d75',
#     '2e9a69f9aa5dd7393f510b0c3ec8c228'],
#    'bundle_iden': 'b70bec411026af1f295057ef171f9e7e'},
#   'b1070c309daeca3d0051b4542e149d01': {'dependability_score': 0,
#    'iden': 'b1070c309daeca3d0051b4542e149d01',
#    'agony': 5493.038556699762,
#    'price': 2676.0,
#    'unrounded_price': 2675.14,
#    'booking_urls': {'bYUjrqQ': {'original_price': 2675.14,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2676.0,
#      'iden': 'bYUjrqQ',
#      'milefy': [{'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2460.0,
#         'qualifying_miles': 2460.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2326.0,
#         'qualifying_miles': 2326.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': ['TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'KKA00NCT',
#        'KKA00NCT',
#        'TL247NCV',
#        'TL247NCV'],
#       'rbds': ['T', 'T', 'T', 'T', 'K', 'K', 'T', 'T']},
#      'url_type': 'web',
#      'unrounded_price': 2675.14,
#      'provider_type': 'OTA',
#      'name': 'Expedia'}},
#    'routing_idens': ['32e93ecf674d32c5807f142ec905573f',
#     'ccef718f2207200f38e3b413bed9361c',
#     '2349567829ae3fdc1ba8f9b335f0e424',
#     '077cd35b3b3ec846c9499fe1095befd7'],
#    'bundle_iden': 'b1171b5aeb264153d89c2eb2f080c4f5'},
#   'd00190247039aac2dc29da70d661f0ef': {'dependability_score': 0,
#    'iden': 'd00190247039aac2dc29da70d661f0ef',
#    'agony': 5292.673122199224,
#    'price': 2506.0,
#    'unrounded_price': 2505.14,
#    'booking_urls': {'eGLrLFq': {'original_price': 2505.14,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2506.0,
#      'iden': 'eGLrLFq',
#      'milefy': [{'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2412.0,
#         'qualifying_miles': 2412.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2363.0,
#         'qualifying_miles': 2363.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': ['TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT'],
#       'rbds': ['T', 'T', 'T', 'T', 'K', 'K', 'K', 'K']},
#      'url_type': 'web',
#      'unrounded_price': 2505.14,
#      'provider_type': 'OTA',
#      'name': 'Expedia'}},
#    'routing_idens': ['2a590900a564b5dfdaf9c2a84c2e8f65',
#     '2833624d1aad78dd00e8b44d0fc6c07c',
#     '2349567829ae3fdc1ba8f9b335f0e424',
#     '8e5021944bc69db74fe987c07a122acb'],
#    'bundle_iden': 'eea05f5c9cb8f5493d689a15bb1de7b3'},
#   '529a2064d1e8e93edee6378d898d6c08': {'dependability_score': 17,
#    'iden': '529a2064d1e8e93edee6378d898d6c08',
#    'agony': 4419.422622433087,
#    'price': 2039.0,
#    'unrounded_price': 2038.02,
#    'booking_urls': {'ahu9dgw': {'original_price': 2038.02,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2039.0,
#      'iden': 'ahu9dgw',
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': [None, None, None, None, None, None, None, None],
#       'rbds': [None, None, None, None, None, None, None, None]},
#      'url_type': 'web',
#      'unrounded_price': 2038.02,
#      'provider_type': 'OTA',
#      'name': 'CheapOair'}},
#    'routing_idens': ['60933ad2e569213a294d053770819c36',
#     'b18072f11ea101716ceda576584ddd3e',
#     '2034310e3e2494039c4fe1f22362909c',
#     '39778b64692831c280ae49071cd72755'],
#    'bundle_iden': '650162e9bbfdf3d9ca201adfab9a883b'},
#   '581a776467a4d17b4c96fe59b507820c': {'dependability_score': 0,
#    'iden': '581a776467a4d17b4c96fe59b507820c',
#    'agony': 8018.46121942609,
#    'price': 4320.0,
#    'unrounded_price': 4319.85,
#    'booking_urls': {'e79k6rv': {'original_price': 4319.85,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': 3888.0,
#      'sort_rank': 0,
#      'price': 4320.0,
#      'iden': 'e79k6rv',
#      'milefy': [{'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 6065.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 989.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 0.0,
#         'qualifying_miles': 773.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 5095.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': [None, None, None, None, None, None, None],
#       'rbds': ['S', 'S', 'Y', 'Y', 'Y', 'Y', 'Y']},
#      'url_type': 'web',
#      'unrounded_price': 4319.85,
#      'provider_type': 'AIR',
#      'name': 'AA'}},
#    'routing_idens': ['472df8eb7ca15d580131f66f8491cbea',
#     '86a00da2fad6bfe2d1a7097985958a42',
#     'b0c98223e2fd695b544df5776f6771e8',
#     '95c9a21bb3e3d2ba09257fb5b4f3dda0'],
#    'bundle_iden': '4fba4bebd3e6c5ef596622285eba51a9'},
#   '81e74a0813df02fe262e4bc9d6dd3abf': {'dependability_score': 0,
#    'iden': '81e74a0813df02fe262e4bc9d6dd3abf',
#    'agony': 5428.869064373437,
#    'price': 2693.0,
#    'unrounded_price': 2692.74,
#    'booking_urls': {'dS8m5Ni': {'original_price': 2692.74,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2693.0,
#      'iden': 'dS8m5Ni',
#      'milefy': [{'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2412.0,
#         'qualifying_miles': 2412.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2394.0,
#         'qualifying_miles': 2394.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': ['SL347NCV',
#        'SL347NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'TL247NCV'],
#       'rbds': ['S', 'S', 'T', 'T', 'T', 'T', 'T', 'T']},
#      'url_type': 'web',
#      'unrounded_price': 2692.74,
#      'provider_type': 'OTA',
#      'name': 'Travelocity'}},
#    'routing_idens': ['23f2663ea5871e78c6c7ee7b0743e97b',
#     'ccef718f2207200f38e3b413bed9361c',
#     'aa89379f8a7c70868caede682cfe8b8f',
#     '5e0a961d0958706cbd4b47372e32489d'],
#    'bundle_iden': 'a60a5b2dfca9cf007cffb17312d4a79c'},
#   '70a1d8ef7079e30dbe5cf785d00315f1': {'dependability_score': 0,
#    'iden': '70a1d8ef7079e30dbe5cf785d00315f1',
#    'agony': 8576.106650900623,
#    'price': 4722.0,
#    'unrounded_price': 4721.05,
#    'booking_urls': {'3hbPTen': {'original_price': 4721.05,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': 4276.0,
#      'sort_rank': 0,
#      'price': 4722.0,
#      'iden': '3hbPTen',
#      'milefy': [{'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 5061.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 989.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 0.0,
#         'qualifying_miles': 773.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 5133.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': [None, None, None, None, None, None, None],
#       'rbds': ['H', 'H', 'Y', 'Y', 'Y', 'Y', 'Y']},
#      'url_type': 'web',
#      'unrounded_price': 4721.05,
#      'provider_type': 'AIR',
#      'name': 'AA'}},
#    'routing_idens': ['c07ada5adcfc891e8559e0a065b14a94',
#     '86a00da2fad6bfe2d1a7097985958a42',
#     'b0c98223e2fd695b544df5776f6771e8',
#     '2e9a69f9aa5dd7393f510b0c3ec8c228'],
#    'bundle_iden': '13e8acaf69b757e2d900d749ec0cbf74'},
#   'c01430eeb3b91ce98526b7015caaa15d': {'dependability_score': 45,
#    'iden': 'c01430eeb3b91ce98526b7015caaa15d',
#    'agony': 8313.01045527809,
#    'price': 4461.0,
#    'unrounded_price': 4460.99,
#    'booking_urls': {'2xLilF3': {'original_price': 4460.99,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': 4011.0,
#      'sort_rank': 0,
#      'price': 4461.0,
#      'iden': '2xLilF3',
#      'milefy': [{'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 4720.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 989.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 0.0,
#         'qualifying_miles': 773.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 4641.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': [None, None, None, None, None, None, None],
#       'rbds': ['L', 'L', 'Y', 'Y', 'Y', 'Y', 'Y']},
#      'url_type': 'web',
#      'unrounded_price': 4460.99,
#      'provider_type': 'AIR',
#      'name': 'AA'}},
#    'routing_idens': ['071457d0fbcce2a13a0af83f3e8b01c3',
#     '86a00da2fad6bfe2d1a7097985958a42',
#     '03a28d5ff6f21826d4dd8d7969b6900a',
#     '73f2365b43fb23b937b34a9946b6c6a7'],
#    'bundle_iden': 'a1d8d538b4831cc0853a2222af4c59a9'},
#   '2b6e3bfd288a4643fabbf24f0615e024': {'dependability_score': 18,
#    'iden': '2b6e3bfd288a4643fabbf24f0615e024',
#    'agony': 5322.442347133516,
#    'price': 2496.0,
#    'unrounded_price': 2495.25,
#    'booking_urls': {'6XNR4s8': {'original_price': 2495.25,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2496.0,
#      'iden': '6XNR4s8',
#      'milefy': [{'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2423.0,
#         'qualifying_miles': 2423.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 0.0,
#         'qualifying_miles': 1137.0,
#         'qualifying_points': 0.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': ['TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT'],
#       'rbds': ['T', 'T', 'T', 'T', 'K', 'K', 'K', 'K']},
#      'url_type': 'web',
#      'unrounded_price': 2495.25,
#      'provider_type': 'OTA',
#      'name': 'Expedia'}},
#    'routing_idens': ['3c574998c62b269adb8e6325f772c74f',
#     'ec139eeb1a6d1d886ea8c3143d47c2ff',
#     'e91e761ff6359e376638c2b25ba18096',
#     '42a7cfeee24211a3fb0786ba08f688cb'],
#    'bundle_iden': 'd639e9886b1e048ad1e905e29731d9ff'},
#   '64d6e6434ca2816c00b7873b0c2b5646': {'dependability_score': 0,
#    'iden': '64d6e6434ca2816c00b7873b0c2b5646',
#    'agony': 5372.365317484062,
#    'price': 2517.0,
#    'unrounded_price': 2516.93,
#    'booking_urls': {'hU7UOjj': {'original_price': 2516.93,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2517.0,
#      'iden': 'hU7UOjj',
#      'milefy': [{'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2481.0,
#         'qualifying_miles': 2481.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2363.0,
#         'qualifying_miles': 2363.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': ['TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT'],
#       'rbds': ['T', 'T', 'T', 'T', 'K', 'K', 'K', 'K']},
#      'url_type': 'web',
#      'unrounded_price': 2516.93,
#      'provider_type': 'OTA',
#      'name': 'Expedia'}},
#    'routing_idens': ['25b9a6a92a93184ef8c02ccac5d63437',
#     'ed9540b3d16f71aef35ade1dcd06fd23',
#     'ffa65a21f762670d4b3ec80fdf25be1d',
#     'cefc2e460db6995c15b8d982539cebba'],
#    'bundle_iden': '499967710f5a344fdb9475bd254f608b'},
#   '9d24dc325d981f21cd1b139f22ba59fc': {'dependability_score': 18,
#    'iden': '9d24dc325d981f21cd1b139f22ba59fc',
#    'agony': 8485.434149150795,
#    'price': 4630.0,
#    'unrounded_price': 4629.85,
#    'booking_urls': {'jZ4zjW': {'original_price': 4629.85,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': 4198.0,
#      'sort_rank': 0,
#      'price': 4630.0,
#      'iden': 'jZ4zjW',
#      'milefy': [{'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 6065.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 989.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 0.0,
#         'qualifying_miles': 773.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 4580.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': [None, None, None, None, None, None, None],
#       'rbds': ['L', 'L', 'Y', 'Y', 'Y', 'Y', 'Y']},
#      'url_type': 'web',
#      'unrounded_price': 4629.85,
#      'provider_type': 'AIR',
#      'name': 'AA'}},
#    'routing_idens': ['a9f0eebf4c128a7b39346471690a8ebf',
#     '86a00da2fad6bfe2d1a7097985958a42',
#     'f682643cc09a16a9fcc226fba4b56d75',
#     'd4785efad6c995f4d026919c51f77a3d'],
#    'bundle_iden': '850c0806515982d24edbfaaab8865393'},
#   'ac9d503a7a584938c4d0a3853a81601c': {'dependability_score': 0,
#    'iden': 'ac9d503a7a584938c4d0a3853a81601c',
#    'agony': 2613.5453136268306,
#    'price': 1044.0,
#    'unrounded_price': 1043.48,
#    'booking_urls': {'gaaMXyr': {'original_price': 1043.48,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 1044.0,
#      'iden': 'gaaMXyr',
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': [None, None, None, None, None, None, None],
#       'rbds': [None, None, None, None, None, None, None]},
#      'url_type': 'web',
#      'unrounded_price': 1043.48,
#      'provider_type': 'OTA',
#      'name': 'CheapOair'}},
#    'routing_idens': ['e1405b3f0f8244d3014983c869aa7eba',
#     'b18072f11ea101716ceda576584ddd3e',
#     'e5606029665f0449643a71a9b3cedd43',
#     '387e4671a203ef28e736ded97ece2187'],
#    'bundle_iden': '877c42a82829b78ff1601ae6ec82dea3'},
#   '2be40447bdbed59051fda9ebda074d61': {'dependability_score': -6,
#    'iden': '2be40447bdbed59051fda9ebda074d61',
#    'agony': 5377.725394009097,
#    'price': 2683.0,
#    'unrounded_price': 2682.35,
#    'booking_urls': {'3aAtZKC': {'original_price': 2682.35,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2683.0,
#      'iden': '3aAtZKC',
#      'milefy': [{'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 4678.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 989.0}},
#       {'program_code': 'IBP',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 376.0,
#         'qualifying_miles': 35.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 5095.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': [None, None, None, None, None, None, None],
#       'rbds': ['S', 'S', 'S', 'S', 'S', 'S', 'S']},
#      'url_type': 'web',
#      'unrounded_price': 2682.35,
#      'provider_type': 'OTA',
#      'name': 'Priceline'}},
#    'routing_idens': ['e8d0c2b363f1e894a45e27039be7ff8a',
#     '1f10033de15e2aadb2d3ca0bc22e28f7',
#     'aee5932418fd0fd23f5ec6dd3227db08',
#     '95c9a21bb3e3d2ba09257fb5b4f3dda0'],
#    'bundle_iden': 'ff996ab0c444ae70b1e2a2ef9dd126c9'},
#   '419ef1501f68eab08f106dea49071fb8': {'dependability_score': 33,
#    'iden': '419ef1501f68eab08f106dea49071fb8',
#    'agony': 8681.93761827725,
#    'price': 4758.0,
#    'unrounded_price': 4757.55,
#    'booking_urls': {'4qgIull': {'original_price': 4757.55,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 4758.0,
#      'iden': '4qgIull',
#      'milefy': [{'program_code': 'ASF',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 5520.0,
#         'qualifying_miles': 5520.0}},
#       {'program_code': 'LMM',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 875.0,
#         'qualifying_miles': 875.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'BAC',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 773.0,
#         'qualifying_miles': 40.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 0.0,
#         'qualifying_miles': 1121.0,
#         'qualifying_points': 0.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': ['KA0W0USA',
#        'KA0W0USA',
#        'GLG2CLS1',
#        'SLG1CLS1',
#        'Y1',
#        'TL247NCV',
#        'TL247NCV'],
#       'rbds': ['K', 'K', 'G', 'S', 'B', 'T', 'T']},
#      'url_type': 'web',
#      'unrounded_price': 4757.55,
#      'provider_type': 'OTA',
#      'name': 'Travelocity'}},
#    'routing_idens': ['1bb15f9bf321967c529a2af9cb9d7006',
#     '27539417a897f210f53a1cde0271b48a',
#     '102a40c7c0ff572f7cdc6da032cff119',
#     'ba885285c138f70c00b29aa681a09fde'],
#    'bundle_iden': 'bae09199259ce485b77eadfef2393f8f'},
#   '77db1a8e27be6df67f98948d1e44e2be': {'dependability_score': 0,
#    'iden': '77db1a8e27be6df67f98948d1e44e2be',
#    'agony': 5274.147570781871,
#    'price': 2551.0,
#    'unrounded_price': 2550.34,
#    'booking_urls': {'SJdUro': {'original_price': 2550.34,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2551.0,
#      'iden': 'SJdUro',
#      'milefy': [{'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2412.0,
#         'qualifying_miles': 2412.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2363.0,
#         'qualifying_miles': 2363.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': ['SL347NCV',
#        'SL347NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT'],
#       'rbds': ['S', 'S', 'T', 'T', 'K', 'K', 'K', 'K']},
#      'url_type': 'web',
#      'unrounded_price': 2550.34,
#      'provider_type': 'OTA',
#      'name': 'Travelocity'}},
#    'routing_idens': ['23f2663ea5871e78c6c7ee7b0743e97b',
#     'f0db0af345593428a62743bf4d6b2de8',
#     '43aceb93bf2ff0f002b535000368fa42',
#     '8e5021944bc69db74fe987c07a122acb'],
#    'bundle_iden': '7f9a65bef4eaa29bd2e94709c8e68f4a'},
#   '32c3b3a62b7f0d0d81628cf3f6f6e15a': {'dependability_score': 45,
#    'iden': '32c3b3a62b7f0d0d81628cf3f6f6e15a',
#    'agony': 8591.563075156024,
#    'price': 4720.0,
#    'unrounded_price': 4719.55,
#    'booking_urls': {'bZ9XnRo': {'original_price': 4719.55,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': 4276.0,
#      'sort_rank': 0,
#      'price': 4720.0,
#      'iden': 'bZ9XnRo',
#      'milefy': [{'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 5061.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 773.0,
#         'qualifying_miles': 989.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 0.0,
#         'qualifying_miles': 773.0}},
#       {'program_code': 'AAA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 0.0,
#         'qualifying_miles': 4641.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': [None, None, None, None, None, None, None],
#       'rbds': ['H', 'H', 'Y', 'Y', 'Y', 'Y', 'Y']},
#      'url_type': 'web',
#      'unrounded_price': 4719.55,
#      'provider_type': 'AIR',
#      'name': 'AA'}},
#    'routing_idens': ['c07ada5adcfc891e8559e0a065b14a94',
#     'bae83f37c3392a3bb3992acd147d9669',
#     'f682643cc09a16a9fcc226fba4b56d75',
#     '73f2365b43fb23b937b34a9946b6c6a7'],
#    'bundle_iden': '6dedfaba2de0a2e3e28baaf57daf5a90'},
#   'f9fd6cd923f7970a8eb21250bde5ddd4': {'dependability_score': 0,
#    'iden': 'f9fd6cd923f7970a8eb21250bde5ddd4',
#    'agony': 4546.328434194485,
#    'price': 2314.0,
#    'unrounded_price': 2313.05,
#    'booking_urls': {'b9Jimvk': {'original_price': 2321.06,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 1,
#      'price': 2322.0,
#      'iden': 'b9Jimvk',
#      'milefy': [{'program_code': 'BAC',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 1147.0,
#         'qualifying_miles': 20.0}},
#       {'program_code': 'IBP',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 159.0,
#         'qualifying_miles': 20.0}},
#       {'program_code': 'BAC',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 193.0,
#         'qualifying_miles': 10.0}},
#       {'program_code': 'IBP',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 1106.0,
#         'qualifying_miles': 90.0}}],
#      'leg_details': {'branded_fares': [None, None, None, None],
#       'fare_basis_codes': ['QLN4C7M5', 'QLN4C7M5', 'QLN4C7M5', 'QLN4C7B5'],
#       'rbds': ['Q', 'Q', 'Q', 'Q']},
#      'url_type': 'web',
#      'unrounded_price': 2321.06,
#      'provider_type': 'OTA',
#      'name': 'Orbitz'},
#     'd9Ugmtc': {'original_price': 2313.05,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2314.0,
#      'iden': 'd9Ugmtc',
#      'milefy': [{'program_code': 'BAC',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 1147.0,
#         'qualifying_miles': 20.0}},
#       {'program_code': 'IBP',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 159.0,
#         'qualifying_miles': 20.0}},
#       {'program_code': 'BAC',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 193.0,
#         'qualifying_miles': 10.0}},
#       {'program_code': 'IBP',
#        'earnings': {'qualifying_segments': 1.0,
#         'miles': 1106.0,
#         'qualifying_miles': 90.0}}],
#      'leg_details': {'branded_fares': [None, None, None, None],
#       'fare_basis_codes': ['QLN4C7M5', 'QLN4C7M5', 'QLN4C7M5', 'QLN4C7B5'],
#       'rbds': ['Q', 'Q', 'Q', 'Q']},
#      'url_type': 'web',
#      'unrounded_price': 2313.05,
#      'provider_type': 'OTA',
#      'name': 'CheapTickets'}},
#    'routing_idens': ['ba3ccb0af9004d653a54ef46685ddcff',
#     'fb83ff645e6b4c13063d946d682e739e',
#     'e42b1e55939b599d675b55cf1b61f19e',
#     '04417c2da6b8f9b38529a29fd691f478'],
#    'bundle_iden': '4e9f5de273e3c150e736ab2a6795eba2'},
#   '5da5d6860d6b4866b68298c1c6b8d603': {'dependability_score': 44,
#    'iden': '5da5d6860d6b4866b68298c1c6b8d603',
#    'agony': 6850.954384189999,
#    'price': 3568.0,
#    'unrounded_price': 3567.85,
#    'booking_urls': {'4mmg8TM': {'original_price': 3567.85,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 3568.0,
#      'iden': '4mmg8TM',
#      'milefy': [{'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 0.0,
#         'qualifying_miles': 7141.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 2500.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 0.0,
#         'qualifying_miles': 1132.0,
#         'qualifying_points': 0.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': [None, None, None, None, None, None, None, None],
#       'rbds': ['B', 'B', 'B', 'B', 'T', 'T', 'T', 'T']},
#      'url_type': 'web',
#      'unrounded_price': 3567.85,
#      'provider_type': 'OTA',
#      'name': 'Priceline'}},
#    'routing_idens': ['20a492dc17b4a8659db8ecc6600e72ff',
#     '2833624d1aad78dd00e8b44d0fc6c07c',
#     'edfbec49ead140b5d106eb970073ad02',
#     '2a28336978fc5df2057872130e3c74e1'],
#    'bundle_iden': '8d187409547c5ff8e0bc3fe3b0380cf2'},
#   '4f41c7a2929d48dadf25c4ee7bc95fcc': {'dependability_score': 0,
#    'iden': '4f41c7a2929d48dadf25c4ee7bc95fcc',
#    'agony': 5265.177420046724,
#    'price': 2470.0,
#    'unrounded_price': 2469.35,
#    'booking_urls': {'flpMK3n': {'original_price': 2469.35,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2470.0,
#      'iden': 'flpMK3n',
#      'milefy': [{'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2423.0,
#         'qualifying_miles': 2423.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'LMM',
#        'earnings': {'miles': 0.0,
#         'qualifying_segments': 2.0,
#         'qualifying_miles': 250.0,
#         'qualifying_points': 0.0}},
#       {'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2315.0,
#         'qualifying_miles': 2315.0}}],
#      'leg_details': {'branded_fares': [None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None,
#        None],
#       'fare_basis_codes': ['TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'TL247NCV',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT',
#        'KKA00NCT'],
#       'rbds': ['T', 'T', 'T', 'T', 'K', 'K', 'K', 'K']},
#      'url_type': 'web',
#      'unrounded_price': 2469.35,
#      'provider_type': 'OTA',
#      'name': 'Expedia'}},
#    'routing_idens': ['877898649fc1f4dbd6bb3136ae9d65c2',
#     '2833624d1aad78dd00e8b44d0fc6c07c',
#     'aa89379f8a7c70868caede682cfe8b8f',
#     'dea2a2f2deba7ae5c5da04bab89107e5'],
#    'bundle_iden': 'd4d9a82278e562213c6d442b5ab47902'},
#   '7c85d4f85e941e65b86f2b437b20a556': {'dependability_score': 0,
#    'iden': '7c85d4f85e941e65b86f2b437b20a556',
#    'agony': 5198.217993829705,
#    'price': 2522.0,
#    'unrounded_price': 2521.33,
#    'booking_urls': {'3z5z53U': {'original_price': 2521.33,
#      'kind': 'flight',
#      'booking_currency': 'USD',
#      'base_fare': None,
#      'sort_rank': 0,
#      'price': 2522.0,
#      'iden': '3z5z53U',
#      'milefy': [{'program_code': 'ACA',
#        'earnings': {'qualifying_segments': 2.0,
#         'miles': 2491.0,
#         'qualifying_miles': 2491.0}},
#       {'program_code': 'LMM',
# ...
#      'short text': 'May have Wi-Fi',
#      'icon': True},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-01T20:45:00-05:00',
#    'from_code': 'YYZ',
#    'cabin': 2,
#    'operating_num': ['AC', 880]},
#   '1ac51448a849f8fcd4c3be61e276cd7c': {'express': '',
#    'marketing_num': ['AA', 145],
#    'arrive_iso': '2019-12-01T13:52:00-06:00',
#    'wifi': False,
#    'equipment': '738',
#    'to_code': 'ORD',
#    'amenities': {'power': {'display text': 'Power',
#      'short text': 'Power',
#      'icon': True},
#     'food': {},
#     'seat': {'display text': 'Average legroom',
#      'short text': 'Average seat',
#      'icon': False},
#     'aircraft': {'display text': '737 (narrowbody)'},
#     'basic_texts': [],
#     'layout': {'display text': '3-3 seat layout'},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {'display text': 'On-demand entertainment',
#      'short text': 'Entertainment',
#      'icon': True},
#     'wifi': {'display text': 'Wi-Fi for purchase',
#      'short text': 'Wi-Fi for purchase',
#      'icon': True},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-01T11:25:00-05:00',
#    'from_code': 'MIA',
#    'cabin': 1,
#    'operating_num': ['AA', 145]},
#   '9bca99ed883eedf692909326242a8420': {'express': '',
#    'marketing_num': ['LX', 2021],
#    'arrive_iso': '2019-12-07T12:15:00+01:00',
#    'wifi': False,
#    'equipment': '221',
#    'to_code': 'ZRH',
#    'amenities': {'power': {},
#     'food': {},
#     'seat': {},
#     'aircraft': {},
#     'basic_texts': [],
#     'layout': {},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {},
#     'wifi': {},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-07T10:00:00+01:00',
#    'from_code': 'MAD',
#    'cabin': 1,
#    'operating_num': ['LX', 2021]},
#   '71df5f5de5b21a427b17ff66c405e84f': {'express': '',
#    'marketing_num': ['AA', 2577],
#    'arrive_iso': '2019-12-10T22:06:00-05:00',
#    'wifi': False,
#    'equipment': '321',
#    'to_code': 'MIA',
#    'amenities': {'power': {'display text': 'No power outlet',
#      'short text': 'No power outlet',
#      'icon': False},
#     'food': {},
#     'seat': {'display text': 'Average legroom',
#      'short text': 'Average seat',
#      'icon': False},
#     'aircraft': {'display text': 'A321 (narrowbody)'},
#     'basic_texts': [],
#     'layout': {'display text': '3-3 seat layout'},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {},
#     'wifi': {'display text': 'Wi-Fi for purchase',
#      'short text': 'Wi-Fi for purchase',
#      'icon': True},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-10T19:56:00-05:00',
#    'from_code': 'CLT',
#    'cabin': 1,
#    'operating_num': ['AA', 2577]},
#   '2dee20900242319164e85daf87b07447': {'express': '',
#    'marketing_num': ['AA', 44],
#    'arrive_iso': '2019-12-02T06:35:00+01:00',
#    'wifi': False,
#    'equipment': '772',
#    'to_code': 'CDG',
#    'amenities': {'power': {'display text': 'Power & USB',
#      'short text': 'Power & USB',
#      'icon': True},
#     'food': {'display text': 'Free meal provided',
#      'short text': 'Free Meal',
#      'icon': True},
#     'seat': {'display text': 'Average legroom',
#      'short text': 'Average seat',
#      'icon': False},
#     'aircraft': {'display text': '777 (widebody)'},
#     'basic_texts': [],
#     'layout': {'display text': '3-4-3 seat layout'},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {'display text': 'On-demand entertainment',
#      'short text': 'Entertainment',
#      'icon': True},
#     'wifi': {'display text': 'Wi-Fi for purchase',
#      'short text': 'Wi-Fi for purchase',
#      'icon': True},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-01T17:29:00-05:00',
#    'from_code': 'JFK',
#    'cabin': 1,
#    'operating_num': ['AA', 44]},
#   'b320f20548775e200e12644e798e7cf0': {'express': '',
#    'marketing_num': ['LH', 7631],
#    'arrive_iso': '2019-12-10T15:25:00-05:00',
#    'wifi': False,
#    'equipment': '763',
#    'to_code': 'EWR',
#    'amenities': {'power': {'display text': 'Power',
#      'short text': 'Power',
#      'icon': True},
#     'food': {'display text': 'Free meal provided',
#      'short text': 'Free Meal',
#      'icon': True},
#     'seat': {'display text': 'Average legroom',
#      'short text': 'Average seat',
#      'icon': False},
#     'aircraft': {'display text': '767 (widebody)'},
#     'basic_texts': [],
#     'layout': {'display text': '2-3-2 seat layout'},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {'display text': 'On-demand entertainment',
#      'short text': 'Entertainment',
#      'icon': True},
#     'wifi': {'display text': 'Wi-Fi for purchase',
#      'short text': 'Wi-Fi for purchase',
#      'icon': True},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-10T12:00:00+00:00',
#    'from_code': 'LHR',
#    'cabin': 1,
#    'operating_num': ['UA', 17]},
#   'bde9d72e2fddf19dc52d6d9f5598410f': {'express': '',
#    'marketing_num': ['AA', 6279],
#    'arrive_iso': '2019-12-07T14:00:00+00:00',
#    'wifi': False,
#    'equipment': '320',
#    'to_code': 'LHR',
#    'amenities': {'power': {},
#     'food': {},
#     'seat': {},
#     'aircraft': {},
#     'basic_texts': [],
#     'layout': {},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {},
#     'wifi': {},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-07T12:30:00+01:00',
#    'from_code': 'MAD',
#    'cabin': 1,
#    'operating_num': ['BA', 459]},
#   '511d8c9ca33d944748a327b8169b82d7': {'express': '',
#    'marketing_num': ['LH', 7706],
#    'arrive_iso': '2019-12-11T23:26:00-05:00',
#    'wifi': False,
#    'equipment': '739',
#    'to_code': 'PBI',
#    'amenities': {'power': {},
#     'food': {},
#     'seat': {},
#     'aircraft': {},
#     'basic_texts': [],
#     'layout': {},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {},
#     'wifi': {},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-11T20:29:00-05:00',
#    'from_code': 'EWR',
#    'cabin': 1,
#    'operating_num': ['UA', 1552]},
#   'd557abd3a5e51b524d5b5855360198e5': {'express': '',
#    'marketing_num': ['LX', 638],
#    'arrive_iso': '2019-12-02T13:50:00+01:00',
#    'wifi': False,
#    'equipment': '223',
#    'to_code': 'CDG',
#    'amenities': {'power': {'display text': 'No power outlet',
#      'short text': 'No power outlet',
#      'icon': False},
#     'food': {},
#     'seat': {'display text': 'Below average legroom',
#      'short text': 'Below average seat',
#      'icon': False},
#     'aircraft': {'display text': 'A223 (narrowbody)'},
#     'basic_texts': [],
#     'layout': {'display text': '2-3 seat layout'},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {'display text': 'No entertainment',
#      'short text': 'No entertainment',
#      'icon': False},
#     'wifi': {'display text': 'No Wi-Fi',
#      'short text': 'No Wi-Fi',
#      'icon': False},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-02T12:30:00+01:00',
#    'from_code': 'ZRH',
#    'cabin': 1,
#    'operating_num': ['LX', 638]},
#   '4fe651dd34477feeedf842d5b2481b92': {'express': '',
#    'marketing_num': ['DY', 7031],
#    'arrive_iso': '2019-12-11T16:00:00-05:00',
#    'wifi': False,
#    'equipment': '789',
#    'to_code': 'FLL',
#    'amenities': {'power': {'display text': 'Power & USB',
#      'short text': 'Power & USB',
#      'icon': True},
#     'food': {'display text': 'Meal available for purchase',
#      'short text': 'Meal for purchase',
#      'icon': True},
#     'seat': {'display text': 'Average legroom',
#      'short text': 'Average seat',
#      'icon': False},
#     'aircraft': {'display text': '787 (widebody)'},
#     'basic_texts': [],
#     'layout': {'display text': '3-3-3 seat layout'},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {'display text': 'On-demand entertainment',
#      'short text': 'Entertainment',
#      'icon': True},
#     'wifi': {'display text': 'May have Wi-Fi',
#      'short text': 'May have Wi-Fi',
#      'icon': True},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-11T11:50:00+01:00',
#    'from_code': 'OSL',
#    'cabin': 1,
#    'operating_num': ['DY', 7031]},
#   '33d15c824ca5d82c0390545e88958dfa': {'express': '',
#    'marketing_num': ['DY', 1337],
#    'arrive_iso': '2019-12-10T23:30:00+01:00',
#    'wifi': False,
#    'equipment': '73H',
#    'to_code': 'SVG',
#    'amenities': {'power': {'display text': 'No power outlet',
#      'short text': 'No power outlet',
#      'icon': False},
#     'food': {},
#     'seat': {'display text': 'Below average legroom',
#      'short text': 'Below average seat',
#      'icon': False},
#     'aircraft': {'display text': '737 (narrowbody)'},
#     'basic_texts': [],
#     'layout': {'display text': '3-3 seat layout'},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {},
#     'wifi': {'display text': 'Wi-Fi for purchase',
#      'short text': 'Wi-Fi for purchase',
#      'icon': True},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-10T20:50:00+00:00',
#    'from_code': 'LGW',
#    'cabin': 1,
#    'operating_num': ['DY', 1337]},
#   '6aa5409a30182e8e86868a97ae991a52': {'express': '',
#    'marketing_num': ['AA', 551],
#    'arrive_iso': '2019-12-01T11:16:00-05:00',
#    'wifi': False,
#    'equipment': '738',
#    'to_code': 'PHL',
#    'amenities': {'power': {'display text': 'Power',
#      'short text': 'Power',
#      'icon': True},
#     'food': {},
#     'seat': {'display text': 'Average legroom',
#      'short text': 'Average seat',
#      'icon': False},
#     'aircraft': {'display text': '737 (narrowbody)'},
#     'basic_texts': [],
#     'layout': {'display text': '3-3 seat layout'},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {'display text': 'On-demand entertainment',
#      'short text': 'Entertainment',
#      'icon': True},
#     'wifi': {'display text': 'Wi-Fi for purchase',
#      'short text': 'Wi-Fi for purchase',
#      'icon': True},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-01T08:30:00-05:00',
#    'from_code': 'MIA',
#    'cabin': 1,
#    'operating_num': ['AA', 551]},
#   '456c57c6e6ac98d6c08aa8bf6a92841c': {'express': '',
#    'marketing_num': ['LH', 2231],
#    'arrive_iso': '2019-12-05T17:15:00+01:00',
#    'wifi': False,
#    'equipment': '32A',
#    'to_code': 'MUC',
#    'amenities': {'power': {'display text': 'No power outlet',
#      'short text': 'No power outlet',
#      'icon': False},
#     'food': {},
#     'seat': {'display text': 'Below average legroom',
#      'short text': 'Below average seat',
#      'icon': False},
#     'aircraft': {'display text': 'A320 (narrowbody)'},
#     'basic_texts': [],
#     'layout': {'display text': '3-3 seat layout'},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {'display text': 'No entertainment',
#      'short text': 'No entertainment',
#      'icon': False},
#     'wifi': {'display text': 'May have Wi-Fi',
#      'short text': 'May have Wi-Fi',
#      'icon': True},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-05T15:50:00+01:00',
#    'from_code': 'CDG',
#    'cabin': 1,
#    'operating_num': ['LH', 2231]},
#   '438536e3346ed5876e55624437ed103b': {'express': '',
#    'marketing_num': ['AA', 750],
#    'arrive_iso': '2019-12-01T16:23:00-06:00',
#    'wifi': False,
#    'equipment': '738',
#    'to_code': 'ORD',
#    'amenities': {'power': {'display text': 'Power',
#      'short text': 'Power',
#      'icon': True},
#     'food': {},
#     'seat': {'display text': 'Average legroom',
#      'short text': 'Average seat',
#      'icon': False},
#     'aircraft': {'display text': '737 (narrowbody)'},
#     'basic_texts': [],
#     'layout': {'display text': '3-3 seat layout'},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {'display text': 'On-demand entertainment',
#      'short text': 'Entertainment',
#      'icon': True},
#     'wifi': {'display text': 'Wi-Fi for purchase',
#      'short text': 'Wi-Fi for purchase',
#      'icon': True},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-01T14:00:00-05:00',
#    'from_code': 'MIA',
#    'cabin': 1,
#    'operating_num': ['AA', 750]},
#   '048e319619873b28f4de3e5371a53e27': {'express': '',
#    'marketing_num': ['BA', 5288],
#    'arrive_iso': '2019-12-10T22:41:00-05:00',
#    'wifi': False,
#    'equipment': '738',
#    'to_code': 'PBI',
#    'amenities': {'power': {'display text': 'Power',
#      'short text': 'Power',
#      'icon': True},
#     'food': {},
#     'seat': {'display text': 'Average legroom',
#      'short text': 'Average seat',
#      'icon': False},
#     'aircraft': {'display text': '737 (narrowbody)'},
#     'basic_texts': ['Seats Assigned at Check-in',
#      'Last to Board',
#      'No Upgrades',
#      'No Changes or Refunds'],
#     'layout': {'display text': '3-3 seat layout'},
#     'basic_header': "Basic Coach;Basic flights are great if you don't have much luggage, don't have seat preferences, and don't need flexibility.",
#     'barebones': True,
#     'entertainment': {'display text': 'On-demand entertainment',
#      'short text': 'Entertainment',
#      'icon': True},
#     'wifi': {'display text': 'Wi-Fi for purchase',
#      'short text': 'Wi-Fi for purchase',
#      'icon': True},
#     'hover_text': 'Basic:;Seats Assigned at Check-in. Last to Board. No Upgrades. No Changes or Refunds.'},
#    'mode': 'air',
#    'depart_iso': '2019-12-10T18:40:00-06:00',
#    'from_code': 'ORD',
#    'cabin': 0,
#    'operating_num': ['AA', 2487]},
#   '1801805defbc7db65a74905fb6377f90': {'express': '',
#    'marketing_num': ['AA', 1845],
#    'arrive_iso': '2019-12-01T17:04:00-05:00',
#    'wifi': False,
#    'equipment': '321',
#    'to_code': 'PHL',
#    'amenities': {'power': {'display text': 'No power outlet',
#      'short text': 'No power outlet',
#      'icon': False},
#     'food': {},
#     'seat': {'display text': 'Average legroom',
#      'short text': 'Average seat',
#      'icon': False},
#     'aircraft': {'display text': 'A321 (narrowbody)'},
#     'basic_texts': [],
#     'layout': {'display text': '3-3 seat layout'},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {},
#     'wifi': {'display text': 'Wi-Fi for purchase',
#      'short text': 'Wi-Fi for purchase',
#      'icon': True},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-01T14:19:00-05:00',
#    'from_code': 'FLL',
#    'cabin': 1,
#    'operating_num': ['AA', 1845]},
#   '20b824bbeb4e5032cfa381b87a3289fb': {'express': 'Air Canada Rouge operated',
#    'marketing_num': ['AC', 1603],
#    'arrive_iso': '2019-12-01T14:25:00-05:00',
#    'wifi': False,
#    'equipment': '763',
#    'to_code': 'YUL',
#    'amenities': {'power': {'display text': 'Power & USB',
#      'short text': 'Power & USB',
#      'icon': True},
#     'food': {},
#     'seat': {'display text': 'Average legroom',
#      'short text': 'Average seat',
#      'icon': False},
#     'aircraft': {'display text': '767 (widebody)'},
#     'basic_texts': [],
#     'layout': {'display text': '2-3-2 seat layout'},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {},
#     'wifi': {'display text': 'May have Wi-Fi',
#      'short text': 'May have Wi-Fi',
#      'icon': True},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-01T11:10:00-05:00',
#    'from_code': 'FLL',
#    'cabin': 1,
#    'operating_num': ['AC', 1603]},
#   '2e337b5eb0a96b0b99d4af662644bb7c': {'express': '',
#    'marketing_num': ['AA', 2595],
#    'arrive_iso': '2019-12-10T20:56:00-05:00',
#    'wifi': False,
#    'equipment': '763',
#    'to_code': 'MIA',
#    'amenities': {'power': {},
#     'food': {},
#     'seat': {'display text': 'Average legroom',
#      'short text': 'Average seat',
#      'icon': False},
#     'aircraft': {'display text': '767 (widebody)'},
#     'basic_texts': [],
#     'layout': {'display text': '2-3-2 seat layout'},
#     'basic_header': '',
#     'barebones': False,
#     'entertainment': {'display text': 'Live TV',
#      'short text': 'Entertainment',
#      'icon': True},
#     'wifi': {'display text': 'Wi-Fi for purchase',
#      'short text': 'Wi-Fi for purchase',
#      'icon': True},
#     'hover_text': ''},
#    'mode': 'air',
#    'depart_iso': '2019-12-10T17:55:00-05:00',
#    'from_code': 'PHL',
#    'cabin': 1,
#    'operating_num': ['AA', 2595]}}}

# %%
# Out:
#       price      agonies                                id  \
# 3501  840.0  2388.801971  0780a81fbbc5ac5f7951fb6d80a66a0a
# 2025  840.0  2273.019662  705cf8c0a76a3276e63358998729abf6
# 1926  840.0  2348.604739  e8bc03f4cf4ec0fac6d02daf7600b575
# 2464  840.0  2264.988398  375c4a96fba030a4b4c424431962f1e7
# 2824  840.0  2354.129484  6f50778b7fd87b9a3a113e2d2754199d
#
#                                                 routing
# 3501  [cf93ba9848d39a0b0df94cae99934983, 4bbfcf4511f...
# 2025  [cf93ba9848d39a0b0df94cae99934983, 4bbfcf4511f...
# 1926  [cf93ba9848d39a0b0df94cae99934983, 4bbfcf4511f...
# 2464  [cf93ba9848d39a0b0df94cae99934983, 4bbfcf4511f...
# 2824  [cf93ba9848d39a0b0df94cae99934983, 4bbfcf4511f...
